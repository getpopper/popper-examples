# %%
import pandas as pd
# %matplotlib inline
import random
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('all.csv')

# %%
df
# Out:
#     iteration  cgroups_enabled  result
# 0           0            False  313.53
# 1           0             True  226.85
# 2           1            False  319.52
# 3           1             True  222.28
# 4           2            False  314.13
# 5           2             True  229.48
# 6           3            False  313.53
# 7           3             True  225.83
# 8           4            False  318.18
# 9           4             True  234.80
# 10          5            False  313.81
# 11          5             True  232.60
# 12          6            False  318.82
# 13          6             True  229.46
# 14          7            False  313.21
# 15          7             True  236.32
# 16          8            False  313.81
# 17          8             True  218.80
# 18          9            False  318.82
# 19          9             True  223.05
# 20         10            False  314.34
# 21         10             True  222.24

# %%
sns_plot = sns.boxplot(data=df, y='result', x='cgroups_enabled')

# %%
sns_plot.figure.savefig('figure1.png')
